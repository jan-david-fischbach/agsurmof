# %%
import numpy as np
from surmof_cavity import ag_surmof_cavity_trref as transmission
from surmof_cavity import eps_cav
import matplotlib.pyplot as plt
import matplotlib as mpl
from functools import partial
from diffaaable.adaptive import adaptive_aaa, next_samples_heat
from diffaaable.selective import selective_refinement_aaa
from diffaaable import aaa
import pickle
from tqdm import tqdm

# %%
# %config InlineBackend.figure_format='retina'

# %%
np.array([448.79110491874115, 438.2930673770547, 412.93727009075883])/300*2*np.pi
# Out:
# array([9.39945892, 9.17958854, 8.64853796])

# %%
toTHz = 300/(2*np.pi)

# %%
all_poles = []
all_residues = []

# %%
ts = 0.025*(np.arange(28)+1)
npoles = 3
for thickness in tqdm(ts[:]):
    f = partial(transmission, thickness=thickness, npoles=npoles)
    poles, residues, evals = selective_refinement_aaa(f, domain=[5.008-1.005j, 20+0.05j], N=400, use_adaptive=False, tol_pol=1e-6)
    all_poles.append(poles)
    all_residues.append(residues)
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# start domain 'd', Dmax=30
# domain 'd' done: [(5.008-1.005j), (20+0.05j)] ->  eval: 400
# start domain 'd1', Dmax=29
# domain 'd1' done: (Array(5.008-0.4775j, dtype=complex128), (20+0.05j)) ->  eval: 400
# start domain 'd11', Dmax=28
# domain 'd11' done: (Array(5.008-0.4775j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd111', Dmax=27
# domain 'd111' done: (Array(5.008-0.21375j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd1111', Dmax=26
# domain 'd1111' done: (Array(5.008-0.21375j, dtype=complex128), Array(8.756+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd11111', Dmax=25
# domain 'd11111' done: (Array(5.008-0.081875j, dtype=complex128), Array(8.756+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd111111', Dmax=24
# domain 'd111111' done: (Array(5.008-0.081875j, dtype=complex128), Array(6.882+0.05j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112', Dmax=24
# domain 'd111112' done: (Array(6.882-0.081875j, dtype=complex128), Array(8.756+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd1111121', Dmax=23
# domain 'd1111121' done: (Array(6.882-0.0159375j, dtype=complex128), Array(8.756+0.05j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122', Dmax=23
# domain 'd1111122' done: (Array(6.882-0.081875j, dtype=complex128), Array(8.756-0.0159375j, dtype=complex128)) ->  eval: 400
# start domain 'd11111221', Dmax=22
# domain 'd11111221' done: (Array(6.882-0.081875j, dtype=complex128), Array(7.819-0.0159375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222', Dmax=22
# domain 'd11111222' done: (Array(7.819-0.081875j, dtype=complex128), Array(8.756-0.0159375j, dtype=complex128)) ->  eval: 400
# start domain 'd111112221', Dmax=21
# domain 'd111112221' done: (Array(7.819-0.04890625j, dtype=complex128), Array(8.756-0.0159375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222', Dmax=21
# domain 'd111112222' done: (Array(7.819-0.081875j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122221', Dmax=20
# domain 'd1111122221' done: (Array(7.819-0.081875j, dtype=complex128), Array(8.2875-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222', Dmax=20
# domain 'd1111122222' done: (Array(8.2875-0.081875j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221', Dmax=19
# domain 'd11111222221' done: (Array(8.2875-0.06539062j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222211', Dmax=18
# domain 'd111112222211' done: (Array(8.2875-0.06539062j, dtype=complex128), Array(8.52175-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212', Dmax=18
# domain 'd111112222212' done: (Array(8.52175-0.06539062j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121', Dmax=17
# domain 'd1111122222121' done: (Array(8.52175-0.05714844j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222122', Dmax=17
# domain 'd1111122222122' done: (Array(8.52175-0.06539062j, dtype=complex128), Array(8.756-0.05714844j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222222', Dmax=19
# domain 'd11111222222' done: (Array(8.2875-0.081875j, dtype=complex128), Array(8.756-0.06539062j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11112', Dmax=25
# domain 'd11112' done: (Array(5.008-0.21375j, dtype=complex128), Array(8.756-0.081875j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112', Dmax=26
# domain 'd1112' done: (Array(8.756-0.21375j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd11121', Dmax=25
# domain 'd11121' done: (Array(8.756-0.081875j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd111211', Dmax=24
# domain 'd111211' done: (Array(8.756-0.081875j, dtype=complex128), Array(10.63+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd1112111', Dmax=23
# domain 'd1112111' done: (Array(8.756-0.0159375j, dtype=complex128), Array(10.63+0.05j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112', Dmax=23
# domain 'd1112112' done: (Array(8.756-0.081875j, dtype=complex128), Array(10.63-0.0159375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111212', Dmax=24
# domain 'd111212' done: (Array(10.63-0.081875j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11122', Dmax=25
# domain 'd11122' done: (Array(8.756-0.21375j, dtype=complex128), Array(12.504-0.081875j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd112', Dmax=27
# domain 'd112' done: (Array(5.008-0.4775j, dtype=complex128), Array(12.504-0.21375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd12', Dmax=28
# domain 'd12' done: (Array(12.504-0.4775j, dtype=complex128), (20+0.05j)) ->  eval: 400
# I am done here
# start domain 'd2', Dmax=29
#   4%|▎         | 1/28 [00:04<02:08,  4.76s/it]
# domain 'd2' done: ((5.008-1.005j), Array(20.-0.4775j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd', Dmax=30
# domain 'd' done: [(5.008-1.005j), (20+0.05j)] ->  eval: 400
# start domain 'd1', Dmax=29
# domain 'd1' done: (Array(5.008-0.4775j, dtype=complex128), (20+0.05j)) ->  eval: 400
# start domain 'd11', Dmax=28
# domain 'd11' done: (Array(5.008-0.4775j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd111', Dmax=27
# domain 'd111' done: (Array(5.008-0.21375j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd1111', Dmax=26
# domain 'd1111' done: (Array(5.008-0.21375j, dtype=complex128), Array(8.756+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd11111', Dmax=25
# domain 'd11111' done: (Array(5.008-0.081875j, dtype=complex128), Array(8.756+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd111111', Dmax=24
# domain 'd111111' done: (Array(5.008-0.081875j, dtype=complex128), Array(6.882+0.05j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112', Dmax=24
# domain 'd111112' done: (Array(6.882-0.081875j, dtype=complex128), Array(8.756+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd1111121', Dmax=23
# domain 'd1111121' done: (Array(6.882-0.0159375j, dtype=complex128), Array(8.756+0.05j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122', Dmax=23
# domain 'd1111122' done: (Array(6.882-0.081875j, dtype=complex128), Array(8.756-0.0159375j, dtype=complex128)) ->  eval: 400
# start domain 'd11111221', Dmax=22
# domain 'd11111221' done: (Array(6.882-0.081875j, dtype=complex128), Array(7.819-0.0159375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222', Dmax=22
# domain 'd11111222' done: (Array(7.819-0.081875j, dtype=complex128), Array(8.756-0.0159375j, dtype=complex128)) ->  eval: 400
# start domain 'd111112221', Dmax=21
# domain 'd111112221' done: (Array(7.819-0.04890625j, dtype=complex128), Array(8.756-0.0159375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222', Dmax=21
# domain 'd111112222' done: (Array(7.819-0.081875j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122221', Dmax=20
# domain 'd1111122221' done: (Array(7.819-0.081875j, dtype=complex128), Array(8.2875-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222', Dmax=20
# domain 'd1111122222' done: (Array(8.2875-0.081875j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221', Dmax=19
# domain 'd11111222221' done: (Array(8.2875-0.06539062j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222211', Dmax=18
# domain 'd111112222211' done: (Array(8.2875-0.06539062j, dtype=complex128), Array(8.52175-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212', Dmax=18
# domain 'd111112222212' done: (Array(8.52175-0.06539062j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121', Dmax=17
# domain 'd1111122222121' done: (Array(8.52175-0.05714844j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221211', Dmax=16
# domain 'd11111222221211' done: (Array(8.52175-0.05714844j, dtype=complex128), Array(8.638875-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222221212', Dmax=16
# domain 'd11111222221212' done: (Array(8.638875-0.05714844j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222212121', Dmax=15
# domain 'd111112222212121' done: (Array(8.638875-0.05302734j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212122', Dmax=15
# domain 'd111112222212122' done: (Array(8.638875-0.05714844j, dtype=complex128), Array(8.756-0.05302734j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121221', Dmax=14
# domain 'd1111122222121221' done: (Array(8.638875-0.05714844j, dtype=complex128), Array(8.6974375-0.05302734j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221212211', Dmax=13
# domain 'd11111222221212211' done: (Array(8.638875-0.05508789j, dtype=complex128), Array(8.6974375-0.05302734j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222221212212', Dmax=13
# domain 'd11111222221212212' done: (Array(8.638875-0.05714844j, dtype=complex128), Array(8.6974375-0.05508789j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222212122121', Dmax=12
# domain 'd111112222212122121' done: (Array(8.638875-0.05714844j, dtype=complex128), Array(8.66815625-0.05508789j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121221211', Dmax=11
# domain 'd1111122222121221211' done: (Array(8.638875-0.05611816j, dtype=complex128), Array(8.66815625-0.05508789j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221212212111', Dmax=10
# domain 'd11111222221212212111' done: (Array(8.638875-0.05611816j, dtype=complex128), Array(8.65351563-0.05508789j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222212122121111', Dmax=9
# domain 'd111112222212122121111' done: (Array(8.638875-0.05560303j, dtype=complex128), Array(8.65351563-0.05508789j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121221211111', Dmax=8
# domain 'd1111122222121221211111' done: (Array(8.638875-0.05560303j, dtype=complex128), Array(8.64619531-0.05508789j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222121221211112', Dmax=8
# domain 'd1111122222121221211112' done: (Array(8.64619531-0.05560303j, dtype=complex128), Array(8.65351563-0.05508789j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221212212111121', Dmax=7
# domain 'd11111222221212212111121' done: (Array(8.64619531-0.05534546j, dtype=complex128), Array(8.65351563-0.05508789j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222221212212111122', Dmax=7
# domain 'd11111222221212212111122' done: (Array(8.64619531-0.05560303j, dtype=complex128), Array(8.65351563-0.05534546j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222212122121111221', Dmax=6
# domain 'd111112222212122121111221' done: (Array(8.64619531-0.05560303j, dtype=complex128), Array(8.64985547-0.05534546j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121221211112211', Dmax=5
# domain 'd1111122222121221211112211' done: (Array(8.64619531-0.05547424j, dtype=complex128), Array(8.64985547-0.05534546j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222121221211112212', Dmax=5
# domain 'd1111122222121221211112212' done: (Array(8.64619531-0.05560303j, dtype=complex128), Array(8.64985547-0.05547424j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221212212111122121', Dmax=4
# domain 'd11111222221212212111122121' done: (Array(8.64619531-0.05560303j, dtype=complex128), Array(8.64802539-0.05547424j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222221212212111122122', Dmax=4
# domain 'd11111222221212212111122122' done: (Array(8.64802539-0.05560303j, dtype=complex128), Array(8.64985547-0.05547424j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222212122121111221221', Dmax=3
# domain 'd111112222212122121111221221' done: (Array(8.64802539-0.05553864j, dtype=complex128), Array(8.64985547-0.05547424j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121221211112212211', Dmax=2
# domain 'd1111122222121221211112212211' done: (Array(8.64802539-0.05553864j, dtype=complex128), Array(8.64894043-0.05547424j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221212212111122122111', Dmax=1
# domain 'd11111222221212212111122122111' done: (Array(8.64802539-0.05550644j, dtype=complex128), Array(8.64894043-0.05547424j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222212122121111221221111', Dmax=0
# domain 'd111112222212122121111221221111' done: (Array(8.64802539-0.05550644j, dtype=complex128), Array(8.64848291-0.05547424j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212122121111221221112', Dmax=0
# domain 'd111112222212122121111221221112' done: (Array(8.64848291-0.05550644j, dtype=complex128), Array(8.64894043-0.05547424j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222221212212111122122112', Dmax=1
# domain 'd11111222221212212111122122112' done: (Array(8.64802539-0.05553864j, dtype=complex128), Array(8.64894043-0.05550644j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222121221211112212212', Dmax=2
# domain 'd1111122222121221211112212212' done: (Array(8.64894043-0.05553864j, dtype=complex128), Array(8.64985547-0.05547424j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212122121111221222', Dmax=3
# domain 'd111112222212122121111221222' done: (Array(8.64802539-0.05560303j, dtype=complex128), Array(8.64985547-0.05553864j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212122121111222', Dmax=6
# domain 'd111112222212122121111222' done: (Array(8.64985547-0.05560303j, dtype=complex128), Array(8.65351563-0.05534546j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212122121112', Dmax=9
# domain 'd111112222212122121112' done: (Array(8.638875-0.05611816j, dtype=complex128), Array(8.65351563-0.05560303j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222221212212112', Dmax=10
# domain 'd11111222221212212112' done: (Array(8.65351563-0.05611816j, dtype=complex128), Array(8.66815625-0.05508789j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222121221212', Dmax=11
# domain 'd1111122222121221212' done: (Array(8.638875-0.05714844j, dtype=complex128), Array(8.66815625-0.05611816j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212122122', Dmax=12
# domain 'd111112222212122122' done: (Array(8.66815625-0.05714844j, dtype=complex128), Array(8.6974375-0.05508789j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222121222', Dmax=14
# domain 'd1111122222121222' done: (Array(8.6974375-0.05714844j, dtype=complex128), Array(8.756-0.05302734j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222122', Dmax=17
# domain 'd1111122222122' done: (Array(8.52175-0.06539062j, dtype=complex128), Array(8.756-0.05714844j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222222', Dmax=19
# domain 'd11111222222' done: (Array(8.2875-0.081875j, dtype=complex128), Array(8.756-0.06539062j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11112', Dmax=25
# domain 'd11112' done: (Array(5.008-0.21375j, dtype=complex128), Array(8.756-0.081875j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112', Dmax=26
# domain 'd1112' done: (Array(8.756-0.21375j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd11121', Dmax=25
# domain 'd11121' done: (Array(8.756-0.081875j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd111211', Dmax=24
# domain 'd111211' done: (Array(8.756-0.081875j, dtype=complex128), Array(10.63+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd1112111', Dmax=23
# domain 'd1112111' done: (Array(8.756-0.0159375j, dtype=complex128), Array(10.63+0.05j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112', Dmax=23
# domain 'd1112112' done: (Array(8.756-0.081875j, dtype=complex128), Array(10.63-0.0159375j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121', Dmax=22
# domain 'd11121121' done: (Array(8.756-0.081875j, dtype=complex128), Array(9.693-0.0159375j, dtype=complex128)) ->  eval: 400
# start domain 'd111211211', Dmax=21
# domain 'd111211211' done: (Array(8.756-0.04890625j, dtype=complex128), Array(9.693-0.0159375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212', Dmax=21
# domain 'd111211212' done: (Array(8.756-0.081875j, dtype=complex128), Array(9.693-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112121', Dmax=20
# domain 'd1112112121' done: (Array(8.756-0.081875j, dtype=complex128), Array(9.2245-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121211', Dmax=19
# domain 'd11121121211' done: (Array(8.756-0.06539062j, dtype=complex128), Array(9.2245-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212111', Dmax=18
# domain 'd111211212111' done: (Array(8.756-0.06539062j, dtype=complex128), Array(8.99025-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212112', Dmax=18
# domain 'd111211212112' done: (Array(8.99025-0.06539062j, dtype=complex128), Array(9.2245-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112121121', Dmax=17
# domain 'd1112112121121' done: (Array(8.99025-0.05714844j, dtype=complex128), Array(9.2245-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112121122', Dmax=17
# domain 'd1112112121122' done: (Array(8.99025-0.06539062j, dtype=complex128), Array(9.2245-0.05714844j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121211221', Dmax=16
# domain 'd11121121211221' done: (Array(8.99025-0.06539062j, dtype=complex128), Array(9.107375-0.05714844j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121211222', Dmax=16
# domain 'd11121121211222' done: (Array(9.107375-0.06539062j, dtype=complex128), Array(9.2245-0.05714844j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212112221', Dmax=15
# domain 'd111211212112221' done: (Array(9.107375-0.06126953j, dtype=complex128), Array(9.2245-0.05714844j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212112222', Dmax=15
# domain 'd111211212112222' done: (Array(9.107375-0.06539062j, dtype=complex128), Array(9.2245-0.06126953j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121212', Dmax=19
# domain 'd11121121212' done: (Array(8.756-0.081875j, dtype=complex128), Array(9.2245-0.06539062j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122', Dmax=20
# domain 'd1112112122' done: (Array(9.2245-0.081875j, dtype=complex128), Array(9.693-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221', Dmax=19
# domain 'd11121121221' done: (Array(9.2245-0.06539062j, dtype=complex128), Array(9.693-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211', Dmax=18
# domain 'd111211212211' done: (Array(9.2245-0.06539062j, dtype=complex128), Array(9.45875-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122111', Dmax=17
# domain 'd1112112122111' done: (Array(9.2245-0.05714844j, dtype=complex128), Array(9.45875-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112', Dmax=17
# domain 'd1112112122112' done: (Array(9.2245-0.06539062j, dtype=complex128), Array(9.45875-0.05714844j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221121', Dmax=16
# domain 'd11121121221121' done: (Array(9.2245-0.06539062j, dtype=complex128), Array(9.341625-0.05714844j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122', Dmax=16
# domain 'd11121121221122' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.45875-0.05714844j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211221', Dmax=15
# domain 'd111211212211221' done: (Array(9.341625-0.06126953j, dtype=complex128), Array(9.45875-0.05714844j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222', Dmax=15
# domain 'd111211212211222' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.45875-0.06126953j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221', Dmax=14
# domain 'd1112112122112221' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.4001875-0.06126953j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122211', Dmax=13
# domain 'd11121121221122211' done: (Array(9.341625-0.06333008j, dtype=complex128), Array(9.4001875-0.06126953j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212', Dmax=13
# domain 'd11121121221122212' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.4001875-0.06333008j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211222121', Dmax=12
# domain 'd111211212211222121' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.37090625-0.06333008j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222122', Dmax=12
# domain 'd111211212211222122' done: (Array(9.37090625-0.06539062j, dtype=complex128), Array(9.4001875-0.06333008j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221221', Dmax=11
# domain 'd1112112122112221221' done: (Array(9.37090625-0.06436035j, dtype=complex128), Array(9.4001875-0.06333008j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112221222', Dmax=11
# domain 'd1112112122112221222' done: (Array(9.37090625-0.06539062j, dtype=complex128), Array(9.4001875-0.06436035j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122212221', Dmax=10
# domain 'd11121121221122212221' done: (Array(9.37090625-0.06539062j, dtype=complex128), Array(9.38554687-0.06436035j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212222', Dmax=10
# domain 'd11121121221122212222' done: (Array(9.38554687-0.06539062j, dtype=complex128), Array(9.4001875-0.06436035j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211222122221', Dmax=9
# domain 'd111211212211222122221' done: (Array(9.38554687-0.06487549j, dtype=complex128), Array(9.4001875-0.06436035j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222122222', Dmax=9
# domain 'd111211212211222122222' done: (Array(9.38554687-0.06539062j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221222221', Dmax=8
# domain 'd1112112122112221222221' done: (Array(9.38554687-0.06539062j, dtype=complex128), Array(9.39286719-0.06487549j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112221222222', Dmax=8
# domain 'd1112112122112221222222' done: (Array(9.39286719-0.06539062j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122212222221', Dmax=7
# domain 'd11121121221122212222221' done: (Array(9.39286719-0.06513306j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211222122222211', Dmax=6
# domain 'd111211212211222122222211' done: (Array(9.39286719-0.06513306j, dtype=complex128), Array(9.39652734-0.06487549j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222122222212', Dmax=6
# domain 'd111211212211222122222212' done: (Array(9.39652734-0.06513306j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221222222121', Dmax=5
# domain 'd1112112122112221222222121' done: (Array(9.39652734-0.06500427j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122212222221211', Dmax=4
# domain 'd11121121221122212222221211' done: (Array(9.39652734-0.06500427j, dtype=complex128), Array(9.39835742-0.06487549j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212222221212', Dmax=4
# domain 'd11121121221122212222221212' done: (Array(9.39835742-0.06500427j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211222122222212121', Dmax=3
# domain 'd111211212211222122222212121' done: (Array(9.39835742-0.06493988j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221222222121211', Dmax=2
# domain 'd1112112122112221222222121211' done: (Array(9.39835742-0.06493988j, dtype=complex128), Array(9.39927246-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122212222221212111', Dmax=1
# domain 'd11121121221122212222221212111' done: (Array(9.39835742-0.06490768j, dtype=complex128), Array(9.39927246-0.06487549j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212222221212112', Dmax=1
# domain 'd11121121221122212222221212112' done: (Array(9.39835742-0.06493988j, dtype=complex128), Array(9.39927246-0.06490768j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211222122222212121121', Dmax=0
# domain 'd111211212211222122222212121121' done: (Array(9.39835742-0.06493988j, dtype=complex128), Array(9.39881494-0.06490768j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222122222212121122', Dmax=0
# domain 'd111211212211222122222212121122' done: (Array(9.39881494-0.06493988j, dtype=complex128), Array(9.39927246-0.06490768j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112221222222121212', Dmax=2
# domain 'd1112112122112221222222121212' done: (Array(9.39927246-0.06493988j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222122222212122', Dmax=3
# domain 'd111211212211222122222212122' done: (Array(9.39835742-0.06500427j, dtype=complex128), Array(9.4001875-0.06493988j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112221222222122', Dmax=5
# domain 'd1112112122112221222222122' done: (Array(9.39652734-0.06513306j, dtype=complex128), Array(9.4001875-0.06500427j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212222222', Dmax=7
# domain 'd11121121221122212222222' done: (Array(9.39286719-0.06539062j, dtype=complex128), Array(9.4001875-0.06513306j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112222', Dmax=14
# domain 'd1112112122112222' done: (Array(9.4001875-0.06539062j, dtype=complex128), Array(9.45875-0.06126953j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212212', Dmax=18
# domain 'd111211212212' done: (Array(9.45875-0.06539062j, dtype=complex128), Array(9.693-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121222', Dmax=19
# domain 'd11121121222' done: (Array(9.2245-0.081875j, dtype=complex128), Array(9.693-0.06539062j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121122', Dmax=22
# domain 'd11121122' done: (Array(9.693-0.081875j, dtype=complex128), Array(10.63-0.0159375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111212', Dmax=24
# domain 'd111212' done: (Array(10.63-0.081875j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11122', Dmax=25
# domain 'd11122' done: (Array(8.756-0.21375j, dtype=complex128), Array(12.504-0.081875j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd112', Dmax=27
#   7%|▋         | 2/28 [00:16<03:48,  8.78s/it]
# domain 'd112' done: (Array(5.008-0.4775j, dtype=complex128), Array(12.504-0.21375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd12', Dmax=28
# domain 'd12' done: (Array(12.504-0.4775j, dtype=complex128), (20+0.05j)) ->  eval: 400
# I am done here
# start domain 'd2', Dmax=29
# domain 'd2' done: ((5.008-1.005j), Array(20.-0.4775j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd', Dmax=30
# domain 'd' done: [(5.008-1.005j), (20+0.05j)] ->  eval: 400
# start domain 'd1', Dmax=29
# domain 'd1' done: (Array(5.008-0.4775j, dtype=complex128), (20+0.05j)) ->  eval: 400
# start domain 'd11', Dmax=28
# domain 'd11' done: (Array(5.008-0.4775j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd111', Dmax=27
# domain 'd111' done: (Array(5.008-0.21375j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd1111', Dmax=26
# domain 'd1111' done: (Array(5.008-0.21375j, dtype=complex128), Array(8.756+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd11111', Dmax=25
# domain 'd11111' done: (Array(5.008-0.081875j, dtype=complex128), Array(8.756+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd111111', Dmax=24
# domain 'd111111' done: (Array(5.008-0.081875j, dtype=complex128), Array(6.882+0.05j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112', Dmax=24
# domain 'd111112' done: (Array(6.882-0.081875j, dtype=complex128), Array(8.756+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd1111121', Dmax=23
# domain 'd1111121' done: (Array(6.882-0.0159375j, dtype=complex128), Array(8.756+0.05j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122', Dmax=23
# domain 'd1111122' done: (Array(6.882-0.081875j, dtype=complex128), Array(8.756-0.0159375j, dtype=complex128)) ->  eval: 400
# start domain 'd11111221', Dmax=22
# domain 'd11111221' done: (Array(6.882-0.081875j, dtype=complex128), Array(7.819-0.0159375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222', Dmax=22
# domain 'd11111222' done: (Array(7.819-0.081875j, dtype=complex128), Array(8.756-0.0159375j, dtype=complex128)) ->  eval: 400
# start domain 'd111112221', Dmax=21
# domain 'd111112221' done: (Array(7.819-0.04890625j, dtype=complex128), Array(8.756-0.0159375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222', Dmax=21
# domain 'd111112222' done: (Array(7.819-0.081875j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122221', Dmax=20
# domain 'd1111122221' done: (Array(7.819-0.081875j, dtype=complex128), Array(8.2875-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222', Dmax=20
# domain 'd1111122222' done: (Array(8.2875-0.081875j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221', Dmax=19
# domain 'd11111222221' done: (Array(8.2875-0.06539062j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222211', Dmax=18
# domain 'd111112222211' done: (Array(8.2875-0.06539062j, dtype=complex128), Array(8.52175-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212', Dmax=18
# domain 'd111112222212' done: (Array(8.52175-0.06539062j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121', Dmax=17
# domain 'd1111122222121' done: (Array(8.52175-0.05714844j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221211', Dmax=16
# domain 'd11111222221211' done: (Array(8.52175-0.05714844j, dtype=complex128), Array(8.638875-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222221212', Dmax=16
# domain 'd11111222221212' done: (Array(8.638875-0.05714844j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222212121', Dmax=15
# domain 'd111112222212121' done: (Array(8.638875-0.05302734j, dtype=complex128), Array(8.756-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212122', Dmax=15
# domain 'd111112222212122' done: (Array(8.638875-0.05714844j, dtype=complex128), Array(8.756-0.05302734j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121221', Dmax=14
# domain 'd1111122222121221' done: (Array(8.638875-0.05714844j, dtype=complex128), Array(8.6974375-0.05302734j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221212211', Dmax=13
# domain 'd11111222221212211' done: (Array(8.638875-0.05508789j, dtype=complex128), Array(8.6974375-0.05302734j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222221212212', Dmax=13
# domain 'd11111222221212212' done: (Array(8.638875-0.05714844j, dtype=complex128), Array(8.6974375-0.05508789j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222212122121', Dmax=12
# domain 'd111112222212122121' done: (Array(8.638875-0.05714844j, dtype=complex128), Array(8.66815625-0.05508789j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121221211', Dmax=11
# domain 'd1111122222121221211' done: (Array(8.638875-0.05611816j, dtype=complex128), Array(8.66815625-0.05508789j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221212212111', Dmax=10
# domain 'd11111222221212212111' done: (Array(8.638875-0.05611816j, dtype=complex128), Array(8.65351563-0.05508789j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222212122121111', Dmax=9
# domain 'd111112222212122121111' done: (Array(8.638875-0.05560303j, dtype=complex128), Array(8.65351563-0.05508789j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121221211111', Dmax=8
# domain 'd1111122222121221211111' done: (Array(8.638875-0.05560303j, dtype=complex128), Array(8.64619531-0.05508789j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222121221211112', Dmax=8
# domain 'd1111122222121221211112' done: (Array(8.64619531-0.05560303j, dtype=complex128), Array(8.65351563-0.05508789j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221212212111121', Dmax=7
# domain 'd11111222221212212111121' done: (Array(8.64619531-0.05534546j, dtype=complex128), Array(8.65351563-0.05508789j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222221212212111122', Dmax=7
# domain 'd11111222221212212111122' done: (Array(8.64619531-0.05560303j, dtype=complex128), Array(8.65351563-0.05534546j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222212122121111221', Dmax=6
# domain 'd111112222212122121111221' done: (Array(8.64619531-0.05560303j, dtype=complex128), Array(8.64985547-0.05534546j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121221211112211', Dmax=5
# domain 'd1111122222121221211112211' done: (Array(8.64619531-0.05547424j, dtype=complex128), Array(8.64985547-0.05534546j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222121221211112212', Dmax=5
# domain 'd1111122222121221211112212' done: (Array(8.64619531-0.05560303j, dtype=complex128), Array(8.64985547-0.05547424j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221212212111122121', Dmax=4
# domain 'd11111222221212212111122121' done: (Array(8.64619531-0.05560303j, dtype=complex128), Array(8.64802539-0.05547424j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222221212212111122122', Dmax=4
# domain 'd11111222221212212111122122' done: (Array(8.64802539-0.05560303j, dtype=complex128), Array(8.64985547-0.05547424j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222212122121111221221', Dmax=3
# domain 'd111112222212122121111221221' done: (Array(8.64802539-0.05553864j, dtype=complex128), Array(8.64985547-0.05547424j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121221211112212211', Dmax=2
# domain 'd1111122222121221211112212211' done: (Array(8.64802539-0.05553864j, dtype=complex128), Array(8.64894043-0.05547424j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221212212111122122111', Dmax=1
# domain 'd11111222221212212111122122111' done: (Array(8.64802539-0.05550644j, dtype=complex128), Array(8.64894043-0.05547424j, dtype=complex128)) ->  eval: 400
# start domain 'd111112222212122121111221221111', Dmax=0
# domain 'd111112222212122121111221221111' done: (Array(8.64802539-0.05550644j, dtype=complex128), Array(8.64848291-0.05547424j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212122121111221221112', Dmax=0
# domain 'd111112222212122121111221221112' done: (Array(8.64848291-0.05550644j, dtype=complex128), Array(8.64894043-0.05547424j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222221212212111122122112', Dmax=1
# domain 'd11111222221212212111122122112' done: (Array(8.64802539-0.05553864j, dtype=complex128), Array(8.64894043-0.05550644j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222121221211112212212', Dmax=2
# domain 'd1111122222121221211112212212' done: (Array(8.64894043-0.05553864j, dtype=complex128), Array(8.64985547-0.05547424j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212122121111221222', Dmax=3
# domain 'd111112222212122121111221222' done: (Array(8.64802539-0.05560303j, dtype=complex128), Array(8.64985547-0.05553864j, dtype=complex128)) ->  eval: 400
# start domain 'd1111122222121221211112212221', Dmax=2
# domain 'd1111122222121221211112212221' done: (Array(8.64802539-0.05560303j, dtype=complex128), Array(8.64894043-0.05553864j, dtype=complex128)) ->  eval: 400
# start domain 'd11111222221212212111122122211', Dmax=1
# domain 'd11111222221212212111122122211' done: (Array(8.64802539-0.05557083j, dtype=complex128), Array(8.64894043-0.05553864j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222221212212111122122212', Dmax=1
# domain 'd11111222221212212111122122212' done: (Array(8.64802539-0.05560303j, dtype=complex128), Array(8.64894043-0.05557083j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222121221211112212222', Dmax=2
# domain 'd1111122222121221211112212222' done: (Array(8.64894043-0.05560303j, dtype=complex128), Array(8.64985547-0.05553864j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212122121111222', Dmax=6
# domain 'd111112222212122121111222' done: (Array(8.64985547-0.05560303j, dtype=complex128), Array(8.65351563-0.05534546j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212122121112', Dmax=9
# domain 'd111112222212122121112' done: (Array(8.638875-0.05611816j, dtype=complex128), Array(8.65351563-0.05560303j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222221212212112', Dmax=10
# domain 'd11111222221212212112' done: (Array(8.65351563-0.05611816j, dtype=complex128), Array(8.66815625-0.05508789j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222121221212', Dmax=11
# domain 'd1111122222121221212' done: (Array(8.638875-0.05714844j, dtype=complex128), Array(8.66815625-0.05611816j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111112222212122122', Dmax=12
# domain 'd111112222212122122' done: (Array(8.66815625-0.05714844j, dtype=complex128), Array(8.6974375-0.05508789j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222121222', Dmax=14
# domain 'd1111122222121222' done: (Array(8.6974375-0.05714844j, dtype=complex128), Array(8.756-0.05302734j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1111122222122', Dmax=17
# domain 'd1111122222122' done: (Array(8.52175-0.06539062j, dtype=complex128), Array(8.756-0.05714844j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11111222222', Dmax=19
# domain 'd11111222222' done: (Array(8.2875-0.081875j, dtype=complex128), Array(8.756-0.06539062j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11112', Dmax=25
# domain 'd11112' done: (Array(5.008-0.21375j, dtype=complex128), Array(8.756-0.081875j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112', Dmax=26
# domain 'd1112' done: (Array(8.756-0.21375j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd11121', Dmax=25
# domain 'd11121' done: (Array(8.756-0.081875j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd111211', Dmax=24
# domain 'd111211' done: (Array(8.756-0.081875j, dtype=complex128), Array(10.63+0.05j, dtype=complex128)) ->  eval: 400
# start domain 'd1112111', Dmax=23
# domain 'd1112111' done: (Array(8.756-0.0159375j, dtype=complex128), Array(10.63+0.05j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112', Dmax=23
# domain 'd1112112' done: (Array(8.756-0.081875j, dtype=complex128), Array(10.63-0.0159375j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121', Dmax=22
# domain 'd11121121' done: (Array(8.756-0.081875j, dtype=complex128), Array(9.693-0.0159375j, dtype=complex128)) ->  eval: 400
# start domain 'd111211211', Dmax=21
# domain 'd111211211' done: (Array(8.756-0.04890625j, dtype=complex128), Array(9.693-0.0159375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212', Dmax=21
# domain 'd111211212' done: (Array(8.756-0.081875j, dtype=complex128), Array(9.693-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112121', Dmax=20
# domain 'd1112112121' done: (Array(8.756-0.081875j, dtype=complex128), Array(9.2245-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121211', Dmax=19
# domain 'd11121121211' done: (Array(8.756-0.06539062j, dtype=complex128), Array(9.2245-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212111', Dmax=18
# domain 'd111211212111' done: (Array(8.756-0.06539062j, dtype=complex128), Array(8.99025-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212112', Dmax=18
# domain 'd111211212112' done: (Array(8.99025-0.06539062j, dtype=complex128), Array(9.2245-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112121121', Dmax=17
# domain 'd1112112121121' done: (Array(8.99025-0.05714844j, dtype=complex128), Array(9.2245-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112121122', Dmax=17
# domain 'd1112112121122' done: (Array(8.99025-0.06539062j, dtype=complex128), Array(9.2245-0.05714844j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121211221', Dmax=16
# domain 'd11121121211221' done: (Array(8.99025-0.06539062j, dtype=complex128), Array(9.107375-0.05714844j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121211222', Dmax=16
# domain 'd11121121211222' done: (Array(9.107375-0.06539062j, dtype=complex128), Array(9.2245-0.05714844j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212112221', Dmax=15
# domain 'd111211212112221' done: (Array(9.107375-0.06126953j, dtype=complex128), Array(9.2245-0.05714844j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212112222', Dmax=15
# domain 'd111211212112222' done: (Array(9.107375-0.06539062j, dtype=complex128), Array(9.2245-0.06126953j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112121122221', Dmax=14
# domain 'd1112112121122221' done: (Array(9.107375-0.06539062j, dtype=complex128), Array(9.1659375-0.06126953j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112121122222', Dmax=14
# domain 'd1112112121122222' done: (Array(9.1659375-0.06539062j, dtype=complex128), Array(9.2245-0.06126953j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121211222221', Dmax=13
# domain 'd11121121211222221' done: (Array(9.1659375-0.06333008j, dtype=complex128), Array(9.2245-0.06126953j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212112222211', Dmax=12
# domain 'd111211212112222211' done: (Array(9.1659375-0.06333008j, dtype=complex128), Array(9.19521875-0.06126953j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112121122222111', Dmax=11
# domain 'd1112112121122222111' done: (Array(9.1659375-0.0622998j, dtype=complex128), Array(9.19521875-0.06126953j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112121122222112', Dmax=11
# domain 'd1112112121122222112' done: (Array(9.1659375-0.06333008j, dtype=complex128), Array(9.19521875-0.0622998j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212112222212', Dmax=12
# domain 'd111211212112222212' done: (Array(9.19521875-0.06333008j, dtype=complex128), Array(9.2245-0.06126953j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121211222222', Dmax=13
# domain 'd11121121211222222' done: (Array(9.1659375-0.06539062j, dtype=complex128), Array(9.2245-0.06333008j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121212', Dmax=19
# domain 'd11121121212' done: (Array(8.756-0.081875j, dtype=complex128), Array(9.2245-0.06539062j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122', Dmax=20
# domain 'd1112112122' done: (Array(9.2245-0.081875j, dtype=complex128), Array(9.693-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221', Dmax=19
# domain 'd11121121221' done: (Array(9.2245-0.06539062j, dtype=complex128), Array(9.693-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211', Dmax=18
# domain 'd111211212211' done: (Array(9.2245-0.06539062j, dtype=complex128), Array(9.45875-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122111', Dmax=17
# domain 'd1112112122111' done: (Array(9.2245-0.05714844j, dtype=complex128), Array(9.45875-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112', Dmax=17
# domain 'd1112112122112' done: (Array(9.2245-0.06539062j, dtype=complex128), Array(9.45875-0.05714844j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221121', Dmax=16
# domain 'd11121121221121' done: (Array(9.2245-0.06539062j, dtype=complex128), Array(9.341625-0.05714844j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122', Dmax=16
# domain 'd11121121221122' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.45875-0.05714844j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211221', Dmax=15
# domain 'd111211212211221' done: (Array(9.341625-0.06126953j, dtype=complex128), Array(9.45875-0.05714844j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222', Dmax=15
# domain 'd111211212211222' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.45875-0.06126953j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221', Dmax=14
# domain 'd1112112122112221' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.4001875-0.06126953j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122211', Dmax=13
# domain 'd11121121221122211' done: (Array(9.341625-0.06333008j, dtype=complex128), Array(9.4001875-0.06126953j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212', Dmax=13
# domain 'd11121121221122212' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.4001875-0.06333008j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211222121', Dmax=12
# domain 'd111211212211222121' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.37090625-0.06333008j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222122', Dmax=12
# domain 'd111211212211222122' done: (Array(9.37090625-0.06539062j, dtype=complex128), Array(9.4001875-0.06333008j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221221', Dmax=11
# domain 'd1112112122112221221' done: (Array(9.37090625-0.06436035j, dtype=complex128), Array(9.4001875-0.06333008j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112221222', Dmax=11
# domain 'd1112112122112221222' done: (Array(9.37090625-0.06539062j, dtype=complex128), Array(9.4001875-0.06436035j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122212221', Dmax=10
# ...
# domain 'd11121121211222222' done: (Array(9.1659375-0.06539062j, dtype=complex128), Array(9.2245-0.06333008j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121212', Dmax=19
# domain 'd11121121212' done: (Array(8.756-0.081875j, dtype=complex128), Array(9.2245-0.06539062j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122', Dmax=20
# domain 'd1112112122' done: (Array(9.2245-0.081875j, dtype=complex128), Array(9.693-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221', Dmax=19
# domain 'd11121121221' done: (Array(9.2245-0.06539062j, dtype=complex128), Array(9.693-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211', Dmax=18
# domain 'd111211212211' done: (Array(9.2245-0.06539062j, dtype=complex128), Array(9.45875-0.04890625j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122111', Dmax=17
# domain 'd1112112122111' done: (Array(9.2245-0.05714844j, dtype=complex128), Array(9.45875-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112', Dmax=17
# domain 'd1112112122112' done: (Array(9.2245-0.06539062j, dtype=complex128), Array(9.45875-0.05714844j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221121', Dmax=16
# domain 'd11121121221121' done: (Array(9.2245-0.06539062j, dtype=complex128), Array(9.341625-0.05714844j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122', Dmax=16
# domain 'd11121121221122' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.45875-0.05714844j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211221', Dmax=15
# domain 'd111211212211221' done: (Array(9.341625-0.06126953j, dtype=complex128), Array(9.45875-0.05714844j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222', Dmax=15
# domain 'd111211212211222' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.45875-0.06126953j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221', Dmax=14
# domain 'd1112112122112221' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.4001875-0.06126953j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122211', Dmax=13
# domain 'd11121121221122211' done: (Array(9.341625-0.06333008j, dtype=complex128), Array(9.4001875-0.06126953j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212', Dmax=13
# domain 'd11121121221122212' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.4001875-0.06333008j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211222121', Dmax=12
# domain 'd111211212211222121' done: (Array(9.341625-0.06539062j, dtype=complex128), Array(9.37090625-0.06333008j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222122', Dmax=12
# domain 'd111211212211222122' done: (Array(9.37090625-0.06539062j, dtype=complex128), Array(9.4001875-0.06333008j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221221', Dmax=11
# domain 'd1112112122112221221' done: (Array(9.37090625-0.06436035j, dtype=complex128), Array(9.4001875-0.06333008j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112221222', Dmax=11
# domain 'd1112112122112221222' done: (Array(9.37090625-0.06539062j, dtype=complex128), Array(9.4001875-0.06436035j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122212221', Dmax=10
# domain 'd11121121221122212221' done: (Array(9.37090625-0.06539062j, dtype=complex128), Array(9.38554687-0.06436035j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212222', Dmax=10
# domain 'd11121121221122212222' done: (Array(9.38554687-0.06539062j, dtype=complex128), Array(9.4001875-0.06436035j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211222122221', Dmax=9
# domain 'd111211212211222122221' done: (Array(9.38554687-0.06487549j, dtype=complex128), Array(9.4001875-0.06436035j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221222211', Dmax=8
# domain 'd1112112122112221222211' done: (Array(9.38554687-0.06487549j, dtype=complex128), Array(9.39286719-0.06436035j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112221222212', Dmax=8
# domain 'd1112112122112221222212' done: (Array(9.39286719-0.06487549j, dtype=complex128), Array(9.4001875-0.06436035j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122212222121', Dmax=7
# domain 'd11121121221122212222121' done: (Array(9.39286719-0.06461792j, dtype=complex128), Array(9.4001875-0.06436035j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212222122', Dmax=7
# domain 'd11121121221122212222122' done: (Array(9.39286719-0.06487549j, dtype=complex128), Array(9.4001875-0.06461792j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211222122221221', Dmax=6
# domain 'd111211212211222122221221' done: (Array(9.39286719-0.06487549j, dtype=complex128), Array(9.39652734-0.06461792j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222122221222', Dmax=6
# domain 'd111211212211222122221222' done: (Array(9.39652734-0.06487549j, dtype=complex128), Array(9.4001875-0.06461792j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221222212221', Dmax=5
# domain 'd1112112122112221222212221' done: (Array(9.39652734-0.0647467j, dtype=complex128), Array(9.4001875-0.06461792j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112221222212222', Dmax=5
# domain 'd1112112122112221222212222' done: (Array(9.39652734-0.06487549j, dtype=complex128), Array(9.4001875-0.0647467j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122212222122221', Dmax=4
# domain 'd11121121221122212222122221' done: (Array(9.39652734-0.06487549j, dtype=complex128), Array(9.39835742-0.0647467j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212222122222', Dmax=4
# domain 'd11121121221122212222122222' done: (Array(9.39835742-0.06487549j, dtype=complex128), Array(9.4001875-0.0647467j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222122222', Dmax=9
# domain 'd111211212211222122222' done: (Array(9.38554687-0.06539062j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221222221', Dmax=8
# domain 'd1112112122112221222221' done: (Array(9.38554687-0.06539062j, dtype=complex128), Array(9.39286719-0.06487549j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112221222222', Dmax=8
# domain 'd1112112122112221222222' done: (Array(9.39286719-0.06539062j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122212222221', Dmax=7
# domain 'd11121121221122212222221' done: (Array(9.39286719-0.06513306j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211222122222211', Dmax=6
# domain 'd111211212211222122222211' done: (Array(9.39286719-0.06513306j, dtype=complex128), Array(9.39652734-0.06487549j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222122222212', Dmax=6
# domain 'd111211212211222122222212' done: (Array(9.39652734-0.06513306j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221222222121', Dmax=5
# domain 'd1112112122112221222222121' done: (Array(9.39652734-0.06500427j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122212222221211', Dmax=4
# domain 'd11121121221122212222221211' done: (Array(9.39652734-0.06500427j, dtype=complex128), Array(9.39835742-0.06487549j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212222221212', Dmax=4
# domain 'd11121121221122212222221212' done: (Array(9.39835742-0.06500427j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211222122222212121', Dmax=3
# domain 'd111211212211222122222212121' done: (Array(9.39835742-0.06493988j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221222222121211', Dmax=2
# domain 'd1112112122112221222222121211' done: (Array(9.39835742-0.06493988j, dtype=complex128), Array(9.39927246-0.06487549j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122212222221212111', Dmax=1
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:39: RuntimeWarning: overflow encountered in exp
#   den = 1 - m1ref_back * m2ref_fwd * np.exp(1j*k3*2*d3)
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:39: RuntimeWarning: invalid value encountered in multiply
#   den = 1 - m1ref_back * m2ref_fwd * np.exp(1j*k3*2*d3)
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:40: RuntimeWarning: overflow encountered in exp
#   tr = m1tr_fwd * m2tr_fwd * np.exp(1j*k3*d3) / den
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:40: RuntimeWarning: invalid value encountered in multiply
#   tr = m1tr_fwd * m2tr_fwd * np.exp(1j*k3*d3) / den
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:40: RuntimeWarning: invalid value encountered in divide
#   tr = m1tr_fwd * m2tr_fwd * np.exp(1j*k3*d3) / den
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:41: RuntimeWarning: overflow encountered in exp
#   ref = m1ref_fwd + m1tr_fwd * m1tr_back * m2ref_fwd * np.exp(1j*k3*2*d3) / den
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:41: RuntimeWarning: invalid value encountered in multiply
#   ref = m1ref_fwd + m1tr_fwd * m1tr_back * m2ref_fwd * np.exp(1j*k3*2*d3) / den
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:41: RuntimeWarning: invalid value encountered in divide
#   ref = m1ref_fwd + m1tr_fwd * m1tr_back * m2ref_fwd * np.exp(1j*k3*2*d3) / den
# domain 'd11121121221122212222221212111' done: (Array(9.39835742-0.06490768j, dtype=complex128), Array(9.39927246-0.06487549j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212222221212112', Dmax=1
# domain 'd11121121221122212222221212112' done: (Array(9.39835742-0.06493988j, dtype=complex128), Array(9.39927246-0.06490768j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112221222222121212', Dmax=2
# domain 'd1112112122112221222222121212' done: (Array(9.39927246-0.06493988j, dtype=complex128), Array(9.4001875-0.06487549j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222122222212122', Dmax=3
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:39: RuntimeWarning: overflow encountered in exp
#   den = 1 - m1ref_back * m2ref_fwd * np.exp(1j*k3*2*d3)
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:39: RuntimeWarning: invalid value encountered in multiply
#   den = 1 - m1ref_back * m2ref_fwd * np.exp(1j*k3*2*d3)
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:40: RuntimeWarning: overflow encountered in exp
#   tr = m1tr_fwd * m2tr_fwd * np.exp(1j*k3*d3) / den
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:40: RuntimeWarning: invalid value encountered in multiply
#   tr = m1tr_fwd * m2tr_fwd * np.exp(1j*k3*d3) / den
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:40: RuntimeWarning: invalid value encountered in divide
#   tr = m1tr_fwd * m2tr_fwd * np.exp(1j*k3*d3) / den
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:41: RuntimeWarning: overflow encountered in exp
#   ref = m1ref_fwd + m1tr_fwd * m1tr_back * m2ref_fwd * np.exp(1j*k3*2*d3) / den
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:41: RuntimeWarning: invalid value encountered in multiply
#   ref = m1ref_fwd + m1tr_fwd * m1tr_back * m2ref_fwd * np.exp(1j*k3*2*d3) / den
# /home/jd/phd/code/agsurmof-cavity-rse/notebooks/surmof_cavity.py:41: RuntimeWarning: invalid value encountered in divide
#   ref = m1ref_fwd + m1tr_fwd * m1tr_back * m2ref_fwd * np.exp(1j*k3*2*d3) / den
# domain 'd111211212211222122222212122' done: (Array(9.39835742-0.06500427j, dtype=complex128), Array(9.4001875-0.06493988j, dtype=complex128)) ->  eval: 400
# start domain 'd1112112122112221222222121221', Dmax=2
# domain 'd1112112122112221222222121221' done: (Array(9.39835742-0.06500427j, dtype=complex128), Array(9.39927246-0.06493988j, dtype=complex128)) ->  eval: 400
# start domain 'd11121121221122212222221212211', Dmax=1
# domain 'd11121121221122212222221212211' done: (Array(9.39835742-0.06497208j, dtype=complex128), Array(9.39927246-0.06493988j, dtype=complex128)) ->  eval: 400
# start domain 'd111211212211222122222212122111', Dmax=0
# domain 'd111211212211222122222212122111' done: (Array(9.39835742-0.06497208j, dtype=complex128), Array(9.39881494-0.06493988j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212211222122222212122112', Dmax=0
# domain 'd111211212211222122222212122112' done: (Array(9.39881494-0.06497208j, dtype=complex128), Array(9.39927246-0.06493988j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212222221212212', Dmax=1
# domain 'd11121121221122212222221212212' done: (Array(9.39835742-0.06500427j, dtype=complex128), Array(9.39927246-0.06497208j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112221222222121222', Dmax=2
# domain 'd1112112122112221222222121222' done: (Array(9.39927246-0.06500427j, dtype=complex128), Array(9.4001875-0.06493988j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112221222222122', Dmax=5
# domain 'd1112112122112221222222122' done: (Array(9.39652734-0.06513306j, dtype=complex128), Array(9.4001875-0.06500427j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121221122212222222', Dmax=7
# domain 'd11121121221122212222222' done: (Array(9.39286719-0.06539062j, dtype=complex128), Array(9.4001875-0.06513306j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd1112112122112222', Dmax=14
# domain 'd1112112122112222' done: (Array(9.4001875-0.06539062j, dtype=complex128), Array(9.45875-0.06126953j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111211212212', Dmax=18
# domain 'd111211212212' done: (Array(9.45875-0.06539062j, dtype=complex128), Array(9.693-0.04890625j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121121222', Dmax=19
# domain 'd11121121222' done: (Array(9.2245-0.081875j, dtype=complex128), Array(9.693-0.06539062j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11121122', Dmax=22
# domain 'd11121122' done: (Array(9.693-0.081875j, dtype=complex128), Array(10.63-0.0159375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd111212', Dmax=24
# domain 'd111212' done: (Array(10.63-0.081875j, dtype=complex128), Array(12.504+0.05j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd11122', Dmax=25
# domain 'd11122' done: (Array(8.756-0.21375j, dtype=complex128), Array(12.504-0.081875j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd112', Dmax=27
# domain 'd112' done: (Array(5.008-0.4775j, dtype=complex128), Array(12.504-0.21375j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd12', Dmax=28
# domain 'd12' done: (Array(12.504-0.4775j, dtype=complex128), (20+0.05j)) ->  eval: 400
# I am done here
# start domain 'd2', Dmax=29
# domain 'd2' done: ((5.008-1.005j), Array(20.-0.4775j, dtype=complex128)) ->  eval: 400
# start domain 'd21', Dmax=28
# domain 'd21' done: ((5.008-1.005j), Array(12.504-0.4775j, dtype=complex128)) ->  eval: 400
# start domain 'd211', Dmax=27
# domain 'd211' done: (Array(5.008-0.74125j, dtype=complex128), Array(12.504-0.4775j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd212', Dmax=27
# domain 'd212' done: ((5.008-1.005j), Array(12.504-0.74125j, dtype=complex128)) ->  eval: 400
# I am done here
# start domain 'd22', Dmax=28
# domain 'd22' done: (Array(12.504-1.005j, dtype=complex128), Array(20.-0.4775j, dtype=complex128)) ->  eval: 400
# I am done here
# 100%|██████████| 28/28 [16:29<00:00, 35.33s/it]

# %%
with open("subdivide3.pkl", "wb") as file:
    pickle.dump({"poles":all_poles, "residues": all_residues, "thickness":ts[:len(all_poles)]}, file)

# %%
cmap = mpl.cm.viridis
norm = mpl.colors.Normalize(vmin=min(ts), vmax=max(ts))
colors = cmap(norm(ts))
for color, poles, residues in zip(colors, all_poles, all_residues):
    filtered_poles = poles[poles.imag<-0.01]
    plt.scatter(filtered_poles.real*toTHz, filtered_poles.imag*toTHz, color=color, s=np.sqrt(np.abs(residues))*100)

plt.colorbar(mpl.cm.ScalarMappable(cmap=cmap, norm=norm), ax=plt.gca(), label="cavity thickness [$\mu m$]")

plt.xlabel("$\Re\{f\}$ [THz]")
plt.ylabel("$\Im\{f\}$ [THz]")
plt.savefig("pole_movement.png", dpi=600)
plt.xlim(380, 490)
plt.ylim(-3.7, -2.5)

plt.xlim(445, 449)
plt.ylim(-3.4, -3)

plt.xlim(435, 439)
plt.ylim(-3.2, -2.95)
# Out:
# (-3.2, -2.95)
